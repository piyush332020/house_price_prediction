# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

df = pd.read_csv("train_house.csv")

x = df.drop(columns=["Price_in_Lakhs"])
y = df["Price_in_Lakhs"]

x = pd.get_dummies(x, drop_first=True)

print("Training Data Shape:", x.shape)

model = RandomForestRegressor(
    n_estimators=15,   
    random_state=42,
    n_jobs=-1          
)

print("Training the model...")
model.fit(x, y)
print("Model training completed!")

test_data = pd.read_csv("test_house.csv")


x_test = pd.get_dummies(test_data, drop_first=True)

x_test = x_test.reindex(columns=x.columns, fill_value=0)

print("Making predictions...")
for i in range(0,99):
    prediction = model.predict(x_test.values)
    print(f"Predictions {i}:")
print(prediction)
# Out:
# Training Data Shape: (250099, 906)
# Training the model...
# Model training completed!
# Making predictions...
# Predictions 0:
# Predictions 1:
# Predictions 2:
# Predictions 3:
# Predictions 4:
# Predictions 5:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 6:
# Predictions 7:
# Predictions 8:
# Predictions 9:
# Predictions 10:
# Predictions 11:
# Predictions 12:
# Predictions 13:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 14:
# Predictions 15:
# Predictions 16:
# Predictions 17:
# Predictions 18:
# Predictions 19:
# Predictions 20:
# Predictions 21:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 22:
# Predictions 23:
# Predictions 24:
# Predictions 25:
# Predictions 26:
# Predictions 27:
# Predictions 28:
# Predictions 29:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 30:
# Predictions 31:
# Predictions 32:
# Predictions 33:
# Predictions 34:
# Predictions 35:
# Predictions 36:
# Predictions 37:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 38:
# Predictions 39:
# Predictions 40:
# Predictions 41:
# Predictions 42:
# Predictions 43:
# Predictions 44:
# Predictions 45:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 46:
# Predictions 47:
# Predictions 48:
# Predictions 49:
# Predictions 50:
# Predictions 51:
# Predictions 52:
# Predictions 53:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 54:
# Predictions 55:
# Predictions 56:
# Predictions 57:
# Predictions 58:
# Predictions 59:
# Predictions 60:
# Predictions 61:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 62:
# Predictions 63:
# Predictions 64:
# Predictions 65:
# Predictions 66:
# Predictions 67:
# Predictions 68:
# Predictions 69:
# Predictions 70:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 71:
# Predictions 72:
# Predictions 73:
# Predictions 74:
# Predictions 75:
# Predictions 76:
# Predictions 77:
# Predictions 78:
# Predictions 79:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 80:
# Predictions 81:
# Predictions 82:
# Predictions 83:
# Predictions 84:
# Predictions 85:
# Predictions 86:
# Predictions 87:
# Predictions 88:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predictions 89:
# Predictions 90:
# Predictions 91:
# Predictions 92:
# Predictions 93:
# Predictions 94:
# Predictions 95:
# Predictions 96:
# Predictions 97:
# Predictions 98:
# [446.79266667  35.30866667 173.66533333 255.78333333 201.17066667
#  103.41533333 245.07733333 360.89933333 404.49533333  72.25533333
#  484.91       200.85933333  84.024      105.68       334.478
#  311.04533333 165.736      198.648       95.82066667 307.026
#  178.08266667 303.256      468.50066667 327.82066667 343.31466667
#  313.954      145.35066667 125.66       299.11       165.97
#  314.21       330.608       81.57733333 261.11666667 235.27133333
#  415.54133333  39.95266667 107.318       63.68266667  87.11266667
#  264.11866667 287.666      384.302       47.58066667 368.25066667
#  336.27266667 146.97466667 297.65866667 259.60333333  72.55
#   32.122      149.344      255.862      375.952      367.50666667
#  347.356       74.64866667 338.03666667 406.012      269.84666667
#  411.78       460.42       409.61       284.782      261.39333333
#   30.598      169.12533333 423.55066667  93.936      372.8
#   85.49266667 343.452      103.73133333 280.57       211.21666667
#  246.31333333 218.12733333  61.904      161.80866667 143.59333333
#  426.734      333.03733333 388.9        306.652      198.584
#  360.63       151.59733333 268.394      245.77866667 307.16466667
#  495.39933333 226.86466667  84.44666667  97.40133333 276.23066667
#   13.4        237.33666667 141.12133333 206.46933333]
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
    print(f"House diff {i}:{abs(y[i]-pred)}")
    total+=abs(y[i]-pred)
print(f"average diffrence in price are :{total/len(prediction)}")
# Out:
# Making diffrence...
# House diff 0:1.632666666666637
# House diff 1:1.7486666666666721
# House diff 2:0.20533333333332848
# House diff 3:0.9433333333333849
# House diff 4:2.1506666666666945
# House diff 5:0.6346666666666891
# House diff 6:1.0226666666666802
# House diff 7:0.059333333333484006
# House diff 8:0.28533333333331257
# House diff 9:1.2653333333333308
# House diff 10:1.1368683772161603e-13
# House diff 11:1.1393333333332976
# House diff 12:1.2539999999999907
# House diff 13:4.263256414560601e-14
# House diff 14:0.24199999999990496
# House diff 15:1.254666666666651
# House diff 16:0.34400000000005093
# House diff 17:0.5079999999999529
# House diff 18:1.4293333333333464
# House diff 19:0.7459999999999241
# House diff 20:0.052666666666709716
# House diff 21:0.1540000000000532
# House diff 22:0.6906666666668002
# House diff 23:1.2006666666666206
# House diff 24:0.6453333333332694
# House diff 25:2.0540000000000305
# House diff 26:0.5106666666666513
# House diff 27:2.842170943040401e-14
# House diff 28:1.67999999999995
# House diff 29:2.842170943040401e-14
# House diff 30:0.0
# House diff 31:0.7119999999999891
# House diff 32:1.007333333333321
# House diff 33:0.5733333333333235
# House diff 34:0.9486666666667247
# House diff 35:0.4386666666667338
# House diff 36:1.727333333333334
# House diff 37:2.07199999999996
# House diff 38:0.3226666666666773
# House diff 39:10.09266666666666
# House diff 40:1.4713333333332912
# House diff 41:2.475999999999999
# House diff 42:0.4979999999999336
# House diff 43:0.2706666666666493
# House diff 44:0.6993333333334135
# House diff 45:2.212666666666678
# House diff 46:0.06466666666668175
# House diff 47:0.9386666666667907
# House diff 48:0.12333333333333485
# House diff 49:1.4210854715202004e-14
# House diff 50:0.7880000000000109
# House diff 51:1.0359999999999445
# House diff 52:0.29800000000005866
# House diff 53:4.171999999999912
# House diff 54:0.6366666666667129
# House diff 55:1.274000000000001
# House diff 56:1.3713333333333395
# House diff 57:1.3266666666667106
# House diff 58:0.19799999999997908
# House diff 59:0.6666666666666288
# House diff 60:1.7053025658242404e-13
# House diff 61:0.0
# House diff 62:1.5799999999998704
# House diff 63:2.612000000000023
# House diff 64:0.4566666666667629
# House diff 65:0.9220000000000041
# House diff 66:1.3453333333333717
# House diff 67:0.9106666666667138
# House diff 68:0.4439999999999742
# House diff 69:1.1368683772161603e-13
# House diff 70:0.05733333333336077
# House diff 71:2.2420000000000755
# House diff 72:1.4286666666666434
# House diff 73:0.12999999999999545
# House diff 74:0.19666666666665833
# House diff 75:0.026666666666613992
# House diff 76:1.2573333333332641
# House diff 77:0.9440000000000097
# House diff 78:0.03133333333332189
# House diff 79:3.1333333333333258
# House diff 80:2.685999999999922
# House diff 81:2.192666666666696
# House diff 82:0.6599999999999682
# House diff 83:0.37800000000004275
# House diff 84:1.8959999999999866
# House diff 85:5.684341886080802e-14
# House diff 86:0.17733333333336532
# House diff 87:0.025999999999953616
# House diff 88:0.4886666666666599
# House diff 89:0.2753333333333785
# House diff 90:0.5906666666668343
# House diff 91:1.5946666666666829
# House diff 92:4.716666666666669
# House diff 93:0.5786666666666775
# House diff 94:1.4806666666666501
# House diff 95:3.552713678800501e-15
# House diff 96:0.3966666666667038
# House diff 97:0.5386666666666429
# House diff 98:6.779333333333369
# average diffrence in price are :1.0650909090909189
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
